# %%
# !python -m spacy download fr_core_news_sm
# Out:
# Collecting fr-core-news-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.0.0/fr_core_news_sm-3.0.0-py3-none-any.whl (17.2 MB)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from fr-core-news-sm==3.0.0) (3.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (3.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (2.0.5)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (1.7.3)
# Requirement already satisfied: pathy in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (0.3.5)
# Requirement already satisfied: setuptools in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (49.2.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (2.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (3.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (0.3.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (8.0.1)
# Requirement already satisfied: jinja2 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (20.8)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (0.7.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (2.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (4.56.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (2.25.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (0.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (1.0.5)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (1.26.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (1.1.1)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages (from pathy->spacy<3.1.0,>=3.0.0->fr-core-news-sm==3.0.0) (3.0.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
import spacy
nlp = spacy.load("fr_core_news_sm")

# %%
Simplon = "De l’analyse du besoin à la data visualisation, en passant par la récolte et le traitement des données. Le développeur data conçoit et exploite les bases de données."

# %%
def return_token(sentence):
    doc = nlp(sentence)
    return [X.text for X in doc]

# %%
return_token(Simplon)
# Out:
# ['De',
#  'l’',
#  'analyse',
#  'du',
#  'besoin',
#  'à',
#  'la',
#  'data',
#  'visualisation',
#  ',',
#  'en',
#  'passant',
#  'par',
#  'la',
#  'récolte',
#  'et',
#  'le',
#  'traitement',
#  'des',
#  'données',
#  '.',
#  'Le',
#  'développeur',
#  'data',
#  'conçoit',
#  'et',
#  'exploite',
#  'les',
#  'bases',
#  'de',
#  'données',
#  '.']

# %%
words_simplon = return_token(Simplon)

# %%
from nltk.corpus import stopwords
stopWords = set(stopwords.words('french'))

# %%
clean_words_simplon = []

for token in words_simplon:
    if token not in stopWords:
        clean_words_simplon.append(token)

# %%
clean_words_simplon
# Out:
# ['De',
#  'l’',
#  'analyse',
#  'besoin',
#  'data',
#  'visualisation',
#  ',',
#  'passant',
#  'récolte',
#  'traitement',
#  'données',
#  '.',
#  'Le',
#  'développeur',
#  'data',
#  'conçoit',
#  'exploite',
#  'bases',
#  'données',
#  '.']

# %%
def return_token_sents(sentence):
    doc = nlp(sentence)
    return [X.text for X in doc.sents]

# %%
return_token_sents(Simplon)
# Out:
# ['De l’analyse du besoin à la data visualisation, en passant par la récolte et le traitement des données.',
#  'Le développeur data conçoit et exploite les bases de données.']

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer(language='french')

def return_stem(sentence):
    doc = nlp(sentence)
    return [stemmer.stem(X.text) for X in doc]

# %%
return_stem(Simplon)
# Out:
# ['de',
#  'l’',
#  'analys',
#  'du',
#  'besoin',
#  'à',
#  'la',
#  'dat',
#  'visualis',
#  ',',
#  'en',
#  'pass',
#  'par',
#  'la',
#  'récolt',
#  'et',
#  'le',
#  'trait',
#  'de',
#  'don',
#  '.',
#  'le',
#  'développeur',
#  'dat',
#  'conçoit',
#  'et',
#  'exploit',
#  'le',
#  'bas',
#  'de',
#  'don',
#  '.']

# %%
trump = "Donald Trump, né le 14 juin 1946, à New York, est un homme d'affaires, animateur de télévision, homme d'État et milliardaire américain. Il est le 45e président des États-Unis, en fonction du 20 janvier 2017 au 20 janvier 2021."

# %%
biden = "Joseph Robinette Biden Jr., dit Joe Biden, né le 20 novembre 1942 à Scranton, est un homme d'État américain. Il est le 47ᵉ vice-président des États-Unis, en fonction de 2009 à 2017, et le 46ᵉ président des États-Unis, depuis le 20 janvier 2021."

# %%
def return_NER(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner le texte et le label pour chaque entité
    return [(X.text, X.label_) for X in doc.ents]

# %%
return_NER(trump)
# Out:
# [('Donald Trump', 'PER'),
#  ('New York', 'LOC'),
#  ('État', 'LOC'),
#  ('États-Unis', 'LOC')]

# %%
from spacy import displacy

doc = nlp(trump)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , né le 14 juin 1946, à
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , est un homme d'affaires, animateur de télévision, homme d'
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     État
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  et milliardaire américain. Il est le 45e président des
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     États-Unis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , en fonction du 20 janvier 2017 au 20 janvier 2021.</div></span>

# %%
def return_POS(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner les étiquettes de chaque token
    return [(X, X.pos_) for X in doc]

# %%
return_POS(trump)
# Out:
# [(Donald, 'NOUN'),
#  (Trump, 'PROPN'),
#  (,, 'PUNCT'),
#  (né, 'VERB'),
#  (le, 'DET'),
#  (14, 'NUM'),
#  (juin, 'NOUN'),
#  (1946, 'NUM'),
#  (,, 'PUNCT'),
#  (à, 'ADP'),
#  (New, 'PROPN'),
#  (York, 'PROPN'),
#  (,, 'PUNCT'),
#  (est, 'AUX'),
#  (un, 'DET'),
#  (homme, 'NOUN'),
#  (d', 'ADP'),
#  (affaires, 'NOUN'),
#  (,, 'PUNCT'),
#  (animateur, 'NOUN'),
#  (de, 'ADP'),
#  (télévision, 'NOUN'),
#  (,, 'PUNCT'),
#  (homme, 'NOUN'),
#  (d', 'ADP'),
#  (État, 'NOUN'),
#  (et, 'CCONJ'),
#  (milliardaire, 'ADJ'),
#  (américain, 'ADJ'),
#  (., 'PUNCT'),
#  (Il, 'PRON'),
#  (est, 'AUX'),
#  (le, 'DET'),
#  (45e, 'ADJ'),
#  (président, 'NOUN'),
#  (des, 'ADP'),
#  (États-Unis, 'PROPN'),
#  (,, 'PUNCT'),
#  (en, 'ADP'),
#  (fonction, 'NOUN'),
#  (du, 'ADP'),
#  (20, 'NUM'),
#  (janvier, 'NOUN'),
#  (2017, 'NUM'),
#  (au, 'ADP'),
#  (20, 'NUM'),
#  (janvier, 'NOUN'),
#  (2021, 'NUM'),
#  (., 'PUNCT')]

# %%
doc = nlp(trump)
displacy.serve(doc, style="dep")
# Out:
# c:\users\levog\simplon\openclassrooms\test\env\lib\site-packages\spacy\displacy\__init__.py:97: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="fr">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="4cc545e7f9a44cf4af03e64430a01bbb-0" class="displacy" width="7225" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Donald</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Trump,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">né</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">14</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">juin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">1946,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">à</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">New</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">York,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">homme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">d'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">affaires,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">animateur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">télévision,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">homme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">d'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">État</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">milliardaire</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">américain.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Il</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">45e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">président</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentC
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...

# %%
import numpy as np

# %%
def return_mean_embedding(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner la moyenne des vecteurs pour chaque phrase
    return np.mean([(X.vector) for X in doc], axis=0)

# %%
return_mean_embedding(Simplon)

# %%
def return_tensor(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner la moyenne des vecteurs pour chaque phrase
    return np.mean([(X.vector) for X in doc], axis=0)

# %%
test_2 = "Le réseau sera bientot rétabli à Marseille"
test_3 = "La panne réseau affecte plusieurs utilisateurs de l'opérateur"
test_4 = "Il fait 18 degrés ici"

# %%
np.linalg.norm(return_tensor(Simplon)-return_tensor(test_2))

# %%
np.linalg.norm(return_tensor(Simplon)-return_tensor(test_3))

# %%
np.linalg.norm(return_tensor(Simplon)-return_tensor(test_4))

# %%
np.linalg.norm(return_tensor(trump)-return_tensor(test_2))

# %%
np.linalg.norm(return_tensor(trump)-return_tensor(test_3))

# %%
np.linalg.norm(return_tensor(trump)-return_tensor(test_4))

# %%
np.linalg.norm(return_tensor(trump)-return_tensor(biden))
